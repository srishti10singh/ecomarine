# %%
style_2 = """

/* cyrillic-ext */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 400;
  font-display: swap;
  src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFWJ0bf8pkAp6a.woff2) format('woff2');
  unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
}
/* cyrillic */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 400;
  font-display: swap;
  src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFUZ0bf8pkAp6a.woff2) format('woff2');
  unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
}
/* greek-ext */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 400;
  font-display: swap;
  src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFWZ0bf8pkAp6a.woff2) format('woff2');
  unicode-range: U+1F00-1FFF;
}
/* greek */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 400;
  font-display: swap;
  src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFVp0bf8pkAp6a.woff2) format('woff2');
  unicode-range: U+0370-03FF;
}
/* vietnamese */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 400;
  font-display: swap;
  src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFWp0bf8pkAp6a.woff2) format('woff2');
  unicode-range: U+0102-0103, U+0110-0111, U+1EA0-1EF9, U+20AB;
}
/* latin-ext */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 400;
  font-display: swap;
  src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFW50bf8pkAp6a.woff2) format('woff2');
  unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
}
/* latin */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 400;
  font-display: swap;
  src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFVZ0bf8pkAg.woff2) format('woff2');
  unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
}
/* cyrillic-ext */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 600;
  font-display: swap;
  src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UNirkOX-hpKKSTj5PW.woff2) format('woff2');
  unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
}
/* cyrillic */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 600;
  font-display: swap;
  src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UNirkOVuhpKKSTj5PW.woff2) format('woff2');
  unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
}
/* greek-ext */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 600;
  font-display: swap;
  src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UNirkOXuhpKKSTj5PW.woff2) format('woff2');
  unicode-range: U+1F00-1FFF;
}
/* greek */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 600;
  font-display: swap;
  src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UNirkOUehpKKSTj5PW.woff2) format('woff2');
  unicode-range: U+0370-03FF;
}
/* vietnamese */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 600;
  font-display: swap;
  src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UNirkOXehpKKSTj5PW.woff2) format('woff2');
  unicode-range: U+0102-0103, U+0110-0111, U+1EA0-1EF9, U+20AB;
}
/* latin-ext */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 600;
  font-display: swap;
  src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UNirkOXOhpKKSTj5PW.woff2) format('woff2');
  unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
}
/* latin */
@font-face {
  font-family: 'Open Sans';
  font-style: normal;
  font-weight: 600;
  font-display: swap;
  src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v17/mem5YaGs126MiZpBA-UNirkOUuhpKKSTjw.woff2) format('woff2');
  unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
}

@font-face {
  font-family: 'Ubuntu Mono';
  font-style: normal;
  font-weight: normal;
  src: local('Ubuntu Mono'), local('UbuntuMono-Regular'), url(https://fonts.gstatic.com/s/ubuntumono/v7/ViZhet7Ak-LRXZMXzuAfkY4P5ICox8Kq3LLUNMylGO4.woff2) format('woff2');
}

.code_cell, .code_cell pre {
	line-height: 1.25 !important;
	font-size: 1.0em !important;
	font-family: 'Ubuntu Mono', monospace, sans-serif !important;
	
}

div #notebook {
	background-color: white;
	font-family: 'Open Sans', Helvetica, sans-serif;
	line-height: 25px;
}

#notebook p {
	margin-top: 0.5em;
	margin-bottom: 1em;
	color: #6d6d6d;
}

#notebook-container {
	margin-top: 2em;
	padding-top: 2em;
	border-top: 4px solid #2b2d6a;
	-webkit-box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
    box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
}

div .input {
	margin-bottom: 1em;
}

.rendered_html h1, .rendered_html h2, .rendered_html h3, .rendered_html h4, .rendered_html h5, .rendered_html h6 {
	color: #292b67;
	font-weight: 600;
}

.rendered_html code {
    background-color: #efefef;
}

.CodeMirror {
	color: #8c8c8c;
	padding: 0.7em;
}

div.input_area {
	border: none;	        
    background-color: rgba(64, 0, 128, 0.03);
    border-top: 2px solid #292b67;
}

div.input_prompt {
	color: #36c9dd;
}

div.output_prompt {
	color: #ffb500;
}

div.cell.selected:before, div.cell.selected.jupyter-soft-selected:before {
	background: #292b67;

}

div.cell.selected, div.cell.selected.jupyter-soft-selected {
    border-color: #292b67;
}

.edit_mode div.cell.selected:before {
	background: #ffb500;

}

.edit_mode div.cell.selected {
	border-color: #ffb500;

}

/* hilights tweaks */
.cm-s-ipython span.cm-number {
	color: #00b1a3;
}

.cm-s-ipython span.cm-builtin {
    color: #00b1a3;
}

.cm-s-ipython span.cm-keyword {
    color: #401e86;
    font-weight: bold;
}
"""
from IPython.core.display import HTML
def notebook_styling():
    styles = style_2
    return HTML("<style>"+styles+"</style>")
notebook_styling()
# Out:
# <style>
#
# /* cyrillic-ext */
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFWJ0bf8pkAp6a.woff2) format('woff2');
#   unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v17/mem8YaGs126MiZpBA-UFUZ0bf8pkAp6a.woff2) format('woff2');
#   unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
# ...

# %%
# !pip install seaborn

# %%
import os
import gc
import re
import tqdm
import copy
# %matplotlib inline
import numpy as np
import pandas as pd
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import matplotlib.image as mpimg
import warnings; warnings.filterwarnings("ignore")

# %%
# Color Palette
custom_colors = ['#292b67', '#9d66ce', '#c490d2', '#ffb500', '#36c9dd']
sns.palplot(sns.color_palette(custom_colors))

# Set Style
sns.set_style("whitegrid")
sns.despine(left=True, bottom=True)

# Set tick size
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)

# %%
def barplot_features(df, feature, title, palette = custom_colors[2:]):
    '''Takes the numerical columns and plots the barplot.'''

    # We need to extract both the name of the category and the no. of appearences
    index = df[feature].value_counts().reset_index()["index"].values
    values = df[feature].value_counts().reset_index()[feature].values 

    plt.figure(figsize = (18, 3))
    sns.barplot(x = index, y = values, palette = palette)
    plt.title(title, fontsize=15)
    plt.show();

    del index, values
    gc.collect()

# %%
def distplot_features(df, feature, title, color = custom_colors[4], categorical=True):
    '''Takes a column from the dataframe and plots the distribution (after count)'''

    if categorical: values = df[feature].value_counts().values
    else: values = df[feature].values

    print('Mean: {:,}'.format(np.mean(values)), "\n"
          'Median: {:,}'.format(np.median(values)), "\n"
          'Max: {:,}'.format(np.max(values)))

    plt.figure(figsize = (18, 3))

    if categorical: sns.distplot(values, hist=False, color = color, kde_kws = {'lw':3})
    else:
        # To speed up the process
        if len(values) > 1000000: sns.distplot(values[::250000], hist=False, color = color, kde_kws = {'lw':3})
        else: sns.distplot(values, hist=False, color = color, kde_kws = {'lw':3})

    plt.title(title, fontsize=15)
    plt.show()    
    del values
    gc.collect()

# %%
df_aquaculture_farmed_fish_production = pd.read_csv('aquaculture-farmes-fish-production.csv', header=0,sep="\t")

# Data Information
print("Rows: {:,}".format(len(df_aquaculture_farmed_fish_production)), "\n" + "Columns: {}".format(len(df_aquaculture_farmed_fish_production.columns)))

# Find Missing Data if any
for column in df_aquaculture_farmed_fish_production.columns:
    if df_aquaculture_farmed_fish_production[column].isna().sum() != 0:
        print("{} has: {:,} ({:.2f}%) missing values.".format(column, df_aquaculture_farmed_fish_production[column].isna().sum(), (df_aquaculture_farmed_fish_production[column].isna().sum()/len(df_aquaculture_farmed_fish_production))*100))

# Fill in missing values in the 'Code' column with -1
df_aquaculture_farmed_fish_production['Code'].fillna(-1, inplace=True)

# Display the first few rows of the DataFrame
df_aquaculture_farmed_fish_production.head()
# Out:
# Rows: 11,657
# Columns: 4
# Code has: 2,773 (23.79%) missing values.
#         Entity Code  Year  Aquaculture production (metric tons)
# 0  Afghanistan  AFG  1969                                  60.0
# 1  Afghanistan  AFG  1970                                  60.0
# 2  Afghanistan  AFG  1971                                  60.0
# 3  Afghanistan  AFG  1972                                  60.0
# 4  Afghanistan  AFG  1973                                  60.0

# %%
numerical_features = ['Aquaculture production (metric tons)']

for feature in numerical_features:
    distplot_features(df_aquaculture_farmed_fish_production, feature=feature, title = feature + " distribution", color = custom_colors[2], categorical=False)
# Out:
# Mean: 1,702,216.4944272367
# Median: 3,706.0
# Max: 106,451,316.5

# %%
categorical_features = ['Entity', 'Code'] 

for feature in categorical_features:
    distplot_features(df_aquaculture_farmed_fish_production, feature=feature, title = feature + " countplot distribution", color = custom_colors[3], categorical=True)
# Out:
# Mean: 48.16942148760331
# Median: 59.0
# Max: 59
# Mean: 59.474489795918366
# Median: 49.0
# Max: 2,773

# %%
df_capture_fisheries_vs_aquaculture = pd.read_csv('fish-and-overfishing/capture-fisheries-vs-aquaculture.csv', names = ['Entity', 'Code', 'Year', 'Aquaculture production (metric tons)', 'Capture fisheries production (metric tons)'], header = 0 , sep="/t")
                                                

# Data Information
print("Rows: {:,}".format(len(df_capture_fisheries_vs_aquaculture)), "\n" + "Columns: {}".format(len(df_capture_fisheries_vs_aquaculture.columns)))

# Find Missing Data if any
for column in df_capture_fisheries_vs_aquaculture.columns:
    if df_capture_fisheries_vs_aquaculture[column].isna().sum() != 0:
        print("{} has: {:,} ({:.2}%) missing values.".format(column, df_capture_fisheries_vs_aquaculture[column].isna().sum(), (df_capture_fisheries_vs_aquaculture[column].isna().sum()/len(df_capture_fisheries_vs_aquaculture))*100))       

# Fill in missing values with "-1"

df_capture_fisheries_vs_aquaculture['Code'] = df_capture_fisheries_vs_aquaculture['Code'].fillna(-1)
df_capture_fisheries_vs_aquaculture['Aquaculture production (metric tons)'] = df_capture_fisheries_vs_aquaculture['Aquaculture production (metric tons)'].fillna(-1)
df_capture_fisheries_vs_aquaculture['Capture fisheries production (metric tons)'] = df_capture_fisheries_vs_aquaculture['Capture fisheries production (metric tons)'].fillna(-1)

df_capture_fisheries_vs_aquaculture.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_capture_fisheries_vs_aquaculture = pd.read_csv('fish-and-overfishing/capture-fisheries-vs-aquaculture.csv', names = ['Entity', 'Code', 'Year', 'Aquaculture production (metric tons)', 'Capture fisheries production (metric tons)'], header = 0 , sep="/t")
#       4 # Data Information
#       5 print("Rows: {:,}".format(len(df_capture_fisheries_vs_aquaculture)), "\n" + "Columns: {}".format(len(df_capture_fisheries_vs_aquaculture.columns)))
#
# ...

# %%
numerical_features = ['Aquaculture production (metric tons)', 'Capture fisheries production (metric tons)']

for feature in numerical_features:
    distplot_features(df_capture_fisheries_vs_aquaculture, feature=feature, title = feature + " distribution", color = custom_colors[2], categorical=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 numerical_features = ['Aquaculture production (metric tons)', 'Capture fisheries production (metric tons)']
#       3 for feature in numerical_features:
# ----> 4     distplot_features(df_capture_fisheries_vs_aquaculture, feature=feature, title = feature + " distribution", color = custom_colors[2], categorical=False)
#
# NameError: name 'df_capture_fisheries_vs_aquaculture' is not defined

# %%
categorical_features = ['Entity', 'Code'] 

for feature in categorical_features:
    distplot_features(df_capture_fisheries_vs_aquaculture, feature=feature, title = feature + " countplot distribution", color = custom_colors[3], categorical=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 categorical_features = ['Entity', 'Code']
#       3 for feature in categorical_features:
# ----> 4     distplot_features(df_capture_fisheries_vs_aquaculture, feature=feature, title = feature + " countplot distribution", color = custom_colors[3], categorical=True)
#
# NameError: name 'df_capture_fisheries_vs_aquaculture' is not defined

# %%
df_capture_fishery_production = pd.read_csv('../input/fish-and-overfishing/capture-fishery-production.csv', names = ['Entity', 'Code', 'Year', 'Capture fisheries production (metric tons)'], header = 0)

# Data Information
print("Rows: {:,}".format(len(df_capture_fishery_production)), "\n" + "Columns: {}".format(len(df_capture_fishery_production.columns)))

# Find Missing Data if any
for column in df_capture_fishery_production.columns:
    if df_capture_fishery_production[column].isna().sum() != 0:
        print("{} has: {:,} ({:.2}%) missing values.".format(column, df_capture_fishery_production[column].isna().sum(), (df_capture_fishery_production[column].isna().sum()/len(df_capture_fishery_production))*100))       

# Fill in missing values with "-1"

df_capture_fishery_production['Code'] = df_capture_fishery_production['Code'].fillna(-1)

df_capture_fishery_production.head()

# %%
numerical_features = ['Capture fisheries production (metric tons)']

for feature in numerical_features:
    distplot_features(df_capture_fishery_production, feature=feature, title = feature + " distribution", color = custom_colors[2], categorical=False)

# %%
categorical_features = ['Entity', 'Code'] 

for feature in categorical_features:
    distplot_features(df_capture_fishery_production, feature=feature, title = feature + " countplot distribution", color = custom_colors[3], categorical=True)

# %%
df_fish_and_seafood_consumption_per_capita = pd.read_csv('../input/fish-and-overfishing/fish-and-seafood-consumption-per-capita.csv', names = ['Entity', 'Code', 'Year', 'Fish, Seafood- Food supply quantity (kg/capita/yr) (FAO, 2020)'], header = 0)

# Data Information
print("Rows: {:,}".format(len(df_fish_and_seafood_consumption_per_capita)), "\n" + "Columns: {}".format(len(df_fish_and_seafood_consumption_per_capita.columns)))

# Find Missing Data if any
for column in df_fish_and_seafood_consumption_per_capita.columns:
    if df_fish_and_seafood_consumption_per_capita[column].isna().sum() != 0:
        print("{} has: {:,} ({:.2}%) missing values.".format(column, df_fish_and_seafood_consumption_per_capita[column].isna().sum(), (df_fish_and_seafood_consumption_per_capita[column].isna().sum()/len(df_fish_and_seafood_consumption_per_capita))*100))       

# Fill in missing values with "-1"

df_fish_and_seafood_consumption_per_capita['Code'] = df_fish_and_seafood_consumption_per_capita['Code'].fillna(-1)

df_fish_and_seafood_consumption_per_capita.head()

# %%
numerical_features = ['Fish, Seafood- Food supply quantity (kg/capita/yr) (FAO, 2020)']

for feature in numerical_features:
    distplot_features(df_fish_and_seafood_consumption_per_capita, feature=feature, title = feature + " distribution", color = custom_colors[2], categorical=False)

# %%
categorical_features = ['Entity', 'Code'] 

for feature in categorical_features:
    distplot_features(df_fish_and_seafood_consumption_per_capita, feature=feature, title = feature + " countplot distribution", color = custom_colors[3], categorical=True)

# %%
df_fish_stocks_within_sustainable_levels = pd.read_csv('../input/fish-and-overfishing/fish-stocks-within-sustainable-levels.csv', names = ['Entity', 'Code', 'Year', 'Share of fish stocks within biologically sustainable levels (FAO, 2020)', 'Share of fish stocks that are overexploited'], header = 0)

# Data Information
print("Rows: {:,}".format(len(df_fish_stocks_within_sustainable_levels)), "\n" + "Columns: {}".format(len(df_fish_stocks_within_sustainable_levels.columns)))

# Find Missing Data if any
for column in df_fish_stocks_within_sustainable_levels.columns:
    if df_fish_stocks_within_sustainable_levels[column].isna().sum() != 0:
        print("{} has: {:,} ({:.2}%) missing values.".format(column, df_fish_stocks_within_sustainable_levels[column].isna().sum(), (df_fish_stocks_within_sustainable_levels[column].isna().sum()/len(df_fish_stocks_within_sustainable_levels))*100))       

# Fill in missing values with "-1"

df_fish_stocks_within_sustainable_levels['Code'] = df_fish_stocks_within_sustainable_levels['Code'].fillna(-1)

df_fish_stocks_within_sustainable_levels.head()

# %%
numerical_features = ['Share of fish stocks within biologically sustainable levels (FAO, 2020)', 'Share of fish stocks that are overexploited']

for feature in numerical_features:
    distplot_features(df_fish_stocks_within_sustainable_levels, feature=feature, title = feature + " distribution", color = custom_colors[2], categorical=False)

# %%
categorical_features = ['Entity'] 

for feature in categorical_features:
    distplot_features(df_fish_stocks_within_sustainable_levels, feature=feature, title = feature + " countplot distribution", color = custom_colors[3], categorical=True)

# %%
categorical_for_bar = ['Code']
for feature in categorical_for_bar:
    barplot_features(df_fish_stocks_within_sustainable_levels, feature=feature, title = feature + " barplot", palette = custom_colors)

# %%
df_global_fishery_catch_by_sector = pd.read_csv('../input/fish-and-overfishing/global-fishery-catch-by-sector.csv', names = ['Entity', 'Code', 'Year', 'Artisanal (small-scale commercial)', 'Discards', 'Industrial (large-scale commercial)', 'Recreational', 'Subsistence'], header = 0)

# Data Information
print("Rows: {:,}".format(len(df_global_fishery_catch_by_sector)), "\n" + "Columns: {}".format(len(df_global_fishery_catch_by_sector.columns)))

# Find Missing Data if any
for column in df_global_fishery_catch_by_sector.columns:
    if df_global_fishery_catch_by_sector[column].isna().sum() != 0:
        print("{} has: {:,} ({:.2}%) missing values.".format(column, df_global_fishery_catch_by_sector[column].isna().sum(), (df_global_fishery_catch_by_sector[column].isna().sum()/len(df_global_fishery_catch_by_sector))*100))       

df_global_fishery_catch_by_sector.head()

# %%
numerical_features = ['Discards', 'Recreational', 'Subsistence', 'Industrial (large-scale commercial)', 'Artisanal (small-scale commercial)']

for feature in numerical_features:
    distplot_features(df_global_fishery_catch_by_sector, feature=feature, title = feature + " distribution", color = custom_colors[2], categorical=False)

# %%
categorical_for_bar = ['Entity', 'Code']
for feature in categorical_for_bar:
    barplot_features(df_global_fishery_catch_by_sector, feature=feature, title = feature + " barplot", palette = custom_colors)

# %%
df_seafood_and_fish_production_thousand_tonnes = pd.read_csv('../input/fish-and-overfishing/seafood-and-fish-production-thousand-tonnes.csv', names = ['Entity', 'Code', 'Year', 'Commodity Balances - Livestock and Fish Primary Equivalent - Pelagic Fish - 2763 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Crustaceans - 2765 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Cephalopods - 2766 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Demersal Fish - 2762 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Freshwater Fish - 2761 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Molluscs, Other - 2767 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Marine Fish, Other - 2764 - Production - 5510 - tonnes'], header = 0)

# Data Information
print("Rows: {:,}".format(len(df_seafood_and_fish_production_thousand_tonnes)), "\n" + "Columns: {}".format(len(df_seafood_and_fish_production_thousand_tonnes.columns)))

# Find Missing Data if any
for column in df_seafood_and_fish_production_thousand_tonnes.columns:
    if df_seafood_and_fish_production_thousand_tonnes[column].isna().sum() != 0:
        print("{} has: {:,} ({:.2}%) missing values.".format(column, df_seafood_and_fish_production_thousand_tonnes[column].isna().sum(), (df_seafood_and_fish_production_thousand_tonnes[column].isna().sum()/len(df_seafood_and_fish_production_thousand_tonnes))*100))       

# Fill in missing values with "-1"

df_seafood_and_fish_production_thousand_tonnes['Code'] = df_seafood_and_fish_production_thousand_tonnes['Code'].fillna(-1)
df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Pelagic Fish - 2763 - Production - 5510 - tonnes'] = df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Pelagic Fish - 2763 - Production - 5510 - tonnes'].fillna(-1)
df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Crustaceans - 2765 - Production - 5510 - tonnes'] = df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Crustaceans - 2765 - Production - 5510 - tonnes'].fillna(-1)
df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Cephalopods - 2766 - Production - 5510 - tonnes'] = df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Cephalopods - 2766 - Production - 5510 - tonnes'].fillna(-1)
df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Demersal Fish - 2762 - Production - 5510 - tonnes'] = df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Demersal Fish - 2762 - Production - 5510 - tonnes'].fillna(-1)
df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Freshwater Fish - 2761 - Production - 5510 - tonnes'] = df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Freshwater Fish - 2761 - Production - 5510 - tonnes'].fillna(-1)
df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Molluscs, Other - 2767 - Production - 5510 - tonnes'] = df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Molluscs, Other - 2767 - Production - 5510 - tonnes'].fillna(-1)
df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Marine Fish, Other - 2764 - Production - 5510 - tonnes'] = df_seafood_and_fish_production_thousand_tonnes['Commodity Balances - Livestock and Fish Primary Equivalent - Marine Fish, Other - 2764 - Production - 5510 - tonnes'].fillna(-1)

df_seafood_and_fish_production_thousand_tonnes.head()

# %%
numerical_features = ['Commodity Balances - Livestock and Fish Primary Equivalent - Marine Fish, Other - 2764 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Pelagic Fish - 2763 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Demersal Fish - 2762 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Molluscs, Other - 2767 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Crustaceans - 2765 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Freshwater Fish - 2761 - Production - 5510 - tonnes', 'Commodity Balances - Livestock and Fish Primary Equivalent - Cephalopods - 2766 - Production - 5510 - tonnes']

for feature in numerical_features:
    distplot_features(df_seafood_and_fish_production_thousand_tonnes, feature=feature, title = feature + " distribution", color = custom_colors[2], categorical=False)

# %%
categorical_features = ['Entity', 'Code'] 

for feature in categorical_features:
    distplot_features(df_seafood_and_fish_production_thousand_tonnes, feature=feature, title = feature + " countplot distribution", color = custom_colors[3], categorical=True)
